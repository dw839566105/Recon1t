# %%
from scipy import interpolate
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import os
import tables

# %%
h = tables.open_file('../result/036_-0.3927.h5','r')
recondata = h.root.Recon
E = recondata[:]['E_sph']
taud = recondata[:]['tau_d']
x = recondata[:]['x_sph']
xt = recondata[:]['x_truth']
y = recondata[:]['y_sph']
yt = recondata[:]['y_truth']
z = recondata[:]['z_sph']
zt = recondata[:]['z_truth']
xl = recondata[:]['x']
h.close()
plt.figure(figsize = (12,6))
plt.subplot(1,2,1)
r1 = x**2 + y**2
H1, xedges, yedges = np.histogram2d(np.nan_to_num(r1), np.nan_to_num(z), bins=50)
X, Y = np.meshgrid(xedges[1:],yedges[1:])
plt.contourf(X,Y,np.log(np.log(np.transpose(H1)+1)+1))
plt.xlabel('x^2+y^2:[m]')
plt.ylabel('z:[m]')
plt.colorbar()
plt.plot(xt[0]**2/1e6,zt[0]/1e3,marker='o',color = 'r')
plt.title('SH recon after correction')
plt.show()

# %%
h = tables.open_file('../result/036_0.3927.h5','r')
recondata = h.root.Recon
E = recondata[:]['E_sph']
taud = recondata[:]['tau_d']
x = recondata[:]['x_sph']
xt = recondata[:]['x_truth']
y = recondata[:]['y_sph']
yt = recondata[:]['y_truth']
z = recondata[:]['z_sph']
zt = recondata[:]['z_truth']
xl = recondata[:]['x']
h.close()
plt.figure(figsize = (12,6))
plt.subplot(1,2,1)
r1 = x**2 + y**2
H1, xedges, yedges = np.histogram2d(np.nan_to_num(r1), np.nan_to_num(z), bins=50)
X, Y = np.meshgrid(xedges[1:],yedges[1:])
plt.contourf(X,Y,np.log(np.log(np.transpose(H1)+1)+1))
plt.xlabel('x^2+y^2:[m]')
plt.ylabel('z:[m]')
plt.colorbar()
plt.plot(xt[0]**2/1e6,zt[0]/1e3,marker='o',color = 'r')
plt.title('SH recon after correction')
plt.show()

# %%
h = tables.open_file('../result/036_0.0000.h5','r')
recondata = h.root.Recon
E = recondata[:]['E_sph']
taud = recondata[:]['tau_d']
x = recondata[:]['x_sph']
xt = recondata[:]['x_truth']
y = recondata[:]['y_sph']
yt = recondata[:]['y_truth']
z = recondata[:]['z_sph']
zt = recondata[:]['z_truth']
xl = recondata[:]['x']
h.close()
plt.figure(figsize = (12,6))
plt.subplot(1,2,1)
r1 = x**2 + y**2
H1, xedges, yedges = np.histogram2d(np.nan_to_num(r1), np.nan_to_num(z), bins=50)
X, Y = np.meshgrid(xedges[1:],yedges[1:])
plt.contourf(X,Y,np.log(np.log(np.transpose(H1)+1)+1))
plt.xlabel('x^2+y^2:[m]')
plt.ylabel('z:[m]')
plt.colorbar()
plt.plot(xt[0]**2/1e6,zt[0]/1e3,marker='o',color = 'r')
plt.title('SH recon after correction')
plt.show()

# %%
h = tables.open_file('../result/036_-3.1416.h5','r')
recondata = h.root.Recon
E = recondata[:]['E_sph']
taud = recondata[:]['tau_d']
x = recondata[:]['x_sph']
xt = recondata[:]['x_truth']
y = recondata[:]['y_sph']
yt = recondata[:]['y_truth']
z = recondata[:]['z_sph']
zt = recondata[:]['z_truth']
xl = recondata[:]['x']
h.close()
plt.figure(figsize = (12,6))
plt.subplot(1,2,1)
r1 = x**2 + y**2
H1, xedges, yedges = np.histogram2d(np.nan_to_num(r1), np.nan_to_num(z), bins=50)
X, Y = np.meshgrid(xedges[1:],yedges[1:])
plt.contourf(X,Y,np.log(np.log(np.transpose(H1)+1)+1))
plt.xlabel('x^2+y^2:[m]')
plt.ylabel('z:[m]')
plt.colorbar()
plt.plot(xt[0]**2/1e6,zt[0]/1e3,marker='o',color = 'r')
plt.title('SH recon after correction')
plt.show()

# %%
h = tables.open_file('../result/036_1.5708.h5','r')
recondata = h.root.Recon
E = recondata[:]['E_sph']
taud = recondata[:]['tau_d']
x = recondata[:]['x_sph']
xt = recondata[:]['x_truth']
y = recondata[:]['y_sph']
yt = recondata[:]['y_truth']
z = recondata[:]['z_sph']
zt = recondata[:]['z_truth']
xl = recondata[:]['x']
h.close()
plt.figure(figsize = (12,6))
plt.subplot(1,2,1)
r1 = x**2 + y**2
H1, xedges, yedges = np.histogram2d(np.nan_to_num(r1), np.nan_to_num(z), bins=50)
X, Y = np.meshgrid(xedges[1:],yedges[1:])
plt.contourf(X,Y,np.log(np.log(np.transpose(H1)+1)+1))
plt.xlabel('x^2+y^2:[m]')
plt.ylabel('z:[m]')
plt.colorbar()
plt.plot(xt[0]**2/1e6,zt[0]/1e3,marker='o',color = 'r')
plt.title('SH recon after correction')
plt.show()

# %%
h = tables.open_file('../result/050/0.50_1.5708.h5','r')
recondata = h.root.Recon
E = recondata[:]['E_sph']
taud = recondata[:]['tau_d']
x = recondata[:]['x_sph']
xt = recondata[:]['x_truth']
y = recondata[:]['y_sph']
yt = recondata[:]['y_truth']
z = recondata[:]['z_sph']
zt = recondata[:]['z_truth']
xl = recondata[:]['x']
h.close()
plt.figure(figsize = (12,6))
plt.subplot(1,2,1)
r1 = x**2 + y**2
H1, xedges, yedges = np.histogram2d(np.nan_to_num(r1), np.nan_to_num(z), bins=50)
X, Y = np.meshgrid(xedges[1:],yedges[1:])
plt.contourf(X,Y,np.log(np.log(np.transpose(H1)+1)+1))
plt.xlabel('x^2+y^2:[m]')
plt.ylabel('z:[m]')
plt.colorbar()
plt.plot(xt[0]**2/1e6,zt[0]/1e3,marker='o',color = 'r')
plt.title('SH recon after correction')
plt.show()

# %%
path = '../result/'
path_list=os.listdir(path)
for filename in path_list:
    if os.path.splitext(filename)[1] == '.h5':
        plt.figure()
        h = tables.open_file(os.path.join(path,filename),'r')
        recondata = h.root.Recon
        E = recondata[:]['E_sph']
        taud = recondata[:]['tau_d']
        x = recondata[:]['x_sph']
        xt = recondata[:]['x_truth']
        y = recondata[:]['y_sph']
        yt = recondata[:]['y_truth']
        z = recondata[:]['z_sph']
        zt = recondata[:]['z_truth']
        xl = recondata[:]['x']
        h.close()
        plt.figure(figsize = (12,6))
        plt.subplot(1,2,1)
        r1 = x**2 + y**2
        H1, xedges, yedges = np.histogram2d(np.nan_to_num(r1), np.nan_to_num(z), bins=50)
        X, Y = np.meshgrid(xedges[1:],yedges[1:])
        plt.contourf(X,Y,np.log(np.log(np.transpose(H1)+1)+1))
        plt.xlabel('x^2+y^2:[m]')
        plt.ylabel('z:[m]')
        plt.colorbar()
        plt.plot(xt[0]**2/1e6,zt[0]/1e3,marker='o',color = 'r')
        plt.title(os.path.join(path,filename))
        plt.show()

# %%
path = '../result/050/'
path_list=os.listdir(path)
for filename in path_list:
    if os.path.splitext(filename)[1] == '.h5':
        plt.figure()
        h = tables.open_file(os.path.join(path,filename),'r')
        recondata = h.root.Recon
        E = recondata[:]['E_sph']
        taud = recondata[:]['tau_d']
        x = recondata[:]['x_sph']
        xt = recondata[:]['x_truth']
        y = recondata[:]['y_sph']
        yt = recondata[:]['y_truth']
        z = recondata[:]['z_sph']
        zt = recondata[:]['z_truth']
        xl = recondata[:]['x']
        h.close()
        plt.figure(figsize = (12,6))
        plt.subplot(1,2,1)
        r1 = x**2 + y**2
        H1, xedges, yedges = np.histogram2d(np.nan_to_num(r1), np.nan_to_num(z), bins=50)
        X, Y = np.meshgrid(xedges[1:],yedges[1:])
        plt.contourf(X,Y,np.log(np.log(np.transpose(H1)+1)+1))
        plt.xlabel('x^2+y^2:[m]')
        plt.ylabel('z:[m]')
        plt.colorbar()
        plt.plot(xt[0]**2/1e6,zt[0]/1e3,marker='o',color = 'r')
        plt.title(os.path.join(path,filename))
        plt.show()

# %%
path = '../result1/0.36_1'
path_list=os.listdir(path)
for filename in path_list:
    if os.path.splitext(filename)[1] == '.h5':
        plt.figure()
        h = tables.open_file(os.path.join(path,filename),'r')
        recondata = h.root.Recon
        E = recondata[:]['E_sph']
        taud = recondata[:]['tau_d']
        x = recondata[:]['x_sph']
        xt = recondata[:]['x_truth']
        y = recondata[:]['y_sph']
        yt = recondata[:]['y_truth']
        z = recondata[:]['z_sph']
        zt = recondata[:]['z_truth']
        xl = recondata[:]['x']
        h.close()
        plt.figure(figsize = (12,6))
        plt.subplot(1,2,1)
        r1 = x**2 + y**2
        H1, xedges, yedges = np.histogram2d(np.nan_to_num(r1), np.nan_to_num(z), bins=50)
        X, Y = np.meshgrid(xedges[1:],yedges[1:])
        plt.contourf(X,Y,np.log(np.log(np.transpose(H1)+1)+1))
        plt.xlabel('x^2+y^2:[m]')
        plt.ylabel('z:[m]')
        plt.colorbar()
        plt.plot(xt[0]**2/1e6,zt[0]/1e3,marker='o',color = 'r')
        plt.title(os.path.join(path,filename))
        plt.show()

# %%
path = '../result1/0.36_1'
path_list=os.listdir(path)
for filename in path_list:
    if os.path.splitext(filename)[1] == '.h5':
        plt.figure()
        h = tables.open_file(os.path.join(path,filename),'r')
        recondata = h.root.Recon
        E = recondata[:]['E_sph']
        taud = recondata[:]['tau_d']
        x = recondata[:]['x_sph']
        xt = recondata[:]['x_truth']
        y = recondata[:]['y_sph']
        yt = recondata[:]['y_truth']
        z = recondata[:]['z_sph']
        zt = recondata[:]['z_truth']
        xl = recondata[:]['x']
        h.close()
        plt.figure(figsize = (12,6))
        plt.subplot(1,2,1)
        r1 = x**2 + y**2
        H1, xedges, yedges = np.histogram2d(np.nan_to_num(r1), np.nan_to_num(z), bins=50)
        X, Y = np.meshgrid(xedges[1:],yedges[1:])
        plt.contourf(X,Y,np.log(np.log(np.transpose(H1)+1)+1))
        plt.xlabel('x^2+y^2:[m]')
        plt.ylabel('z:[m]')
        plt.colorbar()
        plt.plot(xt[0]**2/1e6,zt[0]/1e3,marker='o',color = 'r')
        plt.title(os.path.join(path,filename))
        
        plt.subplot(1,2,2)
        h = tables.open_file(os.path.join('../result/036',filename),'r')
        recondata = h.root.Recon
        E = recondata[:]['E_sph']
        taud = recondata[:]['tau_d']
        x = recondata[:]['x_sph']
        xt = recondata[:]['x_truth']
        y = recondata[:]['y_sph']
        yt = recondata[:]['y_truth']
        z = recondata[:]['z_sph']
        zt = recondata[:]['z_truth']
        xl = recondata[:]['x']
        h.close()
        r1 = x**2 + y**2
        H1, xedges, yedges = np.histogram2d(np.nan_to_num(r1), np.nan_to_num(z), bins=(xedges, yedges))
        X, Y = np.meshgrid(xedges[1:],yedges[1:])
        plt.contourf(X,Y,np.log(np.log(np.transpose(H1)+1)+1))
        plt.xlabel('x^2+y^2:[m]')
        plt.ylabel('z:[m]')
        plt.colorbar()
        plt.plot(xt[0]**2/1e6,zt[0]/1e3,marker='o',color = 'r')
        plt.title(os.path.join('../result',filename))
        plt.show()

# %%
path = '../result1/036'
path_list=os.listdir(path)
for filename in path_list:
    if os.path.splitext(filename)[1] == '.h5':
        plt.figure()
        h = tables.open_file(os.path.join(path,filename),'r')
        recondata = h.root.Recon
        E = recondata[:]['E_sph']
        taud = recondata[:]['tau_d']
        x = recondata[:]['x_sph']
        xt = recondata[:]['x_truth']
        y = recondata[:]['y_sph']
        yt = recondata[:]['y_truth']
        z = recondata[:]['z_sph']
        zt = recondata[:]['z_truth']
        xl = recondata[:]['x']
        h.close()
        plt.figure(figsize = (12,6))
        plt.subplot(1,2,1)
        r1 = x**2 + y**2
        H1, xedges, yedges = np.histogram2d(np.nan_to_num(r1), np.nan_to_num(z), bins=50)
        X, Y = np.meshgrid(xedges[1:],yedges[1:])
        plt.contourf(X,Y,np.log(np.log(np.transpose(H1)+1)+1))
        plt.xlabel('x^2+y^2:[m]')
        plt.ylabel('z:[m]')
        plt.colorbar()
        plt.plot(xt[0]**2/1e6,zt[0]/1e3,marker='o',color = 'r')
        # plt.title(os.path.join(path,filename))
        plt.title('After Smooth')
        
        plt.subplot(1,2,2)
        h = tables.open_file(os.path.join('../result1/0.36',filename),'r')
        recondata = h.root.Recon
        E = recondata[:]['E_sph']
        taud = recondata[:]['tau_d']
        x = recondata[:]['x_sph']
        xt = recondata[:]['x_truth']
        y = recondata[:]['y_sph']
        yt = recondata[:]['y_truth']
        z = recondata[:]['z_sph']
        zt = recondata[:]['z_truth']
        xl = recondata[:]['x']
        h.close()
        r1 = x**2 + y**2
        H1, xedges, yedges = np.histogram2d(np.nan_to_num(r1), np.nan_to_num(z), bins=(xedges, yedges))
        X, Y = np.meshgrid(xedges[1:],yedges[1:])
        plt.contourf(X,Y,np.log(np.log(np.transpose(H1)+1)+1))
        plt.xlabel('x^2+y^2:[m]')
        plt.ylabel('z:[m]')
        plt.colorbar()
        plt.plot(xt[0]**2/1e6,zt[0]/1e3,marker='o',color = 'r')
        # plt.title(os.path.join('../result/036',filename))
        plt.title('Before Smooth')
        plt.show()

# %%
h = tables.open_file('/home/douwei/coeff.h5','r')
recondata = h.root.coeff
plt.plot(np.transpose(recondata[:]))

h = tables.open_file('/home/douwei/coeff1.h5','r')
recondata = h.root.coeff
plt.plot(np.transpose(recondata[:]))
# Out:
# [<matplotlib.lines.Line2D at 0x7f911d43dac8>,
#  <matplotlib.lines.Line2D at 0x7f911d43dc18>,
#  <matplotlib.lines.Line2D at 0x7f911d43dd68>,
#  <matplotlib.lines.Line2D at 0x7f911d43deb8>,
#  <matplotlib.lines.Line2D at 0x7f911d450048>]

# %%
path = '../result1/050'
path_list=os.listdir(path)
for filename in path_list:
    if os.path.splitext(filename)[1] == '.h5':
        plt.figure()
        h = tables.open_file(os.path.join(path,filename),'r')
        recondata = h.root.Recon
        E = recondata[:]['E_sph']
        taud = recondata[:]['tau_d']
        x = recondata[:]['x_sph']
        xt = recondata[:]['x_truth']
        y = recondata[:]['y_sph']
        yt = recondata[:]['y_truth']
        z = recondata[:]['z_sph']
        zt = recondata[:]['z_truth']
        xl = recondata[:]['x']
        h.close()
        plt.figure(figsize = (12,6))
        plt.subplot(1,2,1)
        r1 = x**2 + y**2
        H1, xedges, yedges = np.histogram2d(np.nan_to_num(r1), np.nan_to_num(z), bins=50)
        X, Y = np.meshgrid(xedges[1:],yedges[1:])
        plt.contourf(X,Y,np.log(np.log(np.transpose(H1)+1)+1))
        plt.xlabel('x^2+y^2:[m]')
        plt.ylabel('z:[m]')
        plt.colorbar()
        plt.plot(xt[0]**2/1e6,zt[0]/1e3,marker='o',color = 'r')
        #plt.title(os.path.join(path,filename))
        plt.title('After smooth')
        
        plt.subplot(1,2,2)
        h = tables.open_file(os.path.join('../result1/0.50',filename),'r')
        recondata = h.root.Recon
        E = recondata[:]['E_sph']
        taud = recondata[:]['tau_d']
        x = recondata[:]['x_sph']
        xt = recondata[:]['x_truth']
        y = recondata[:]['y_sph']
        yt = recondata[:]['y_truth']
        z = recondata[:]['z_sph']
        zt = recondata[:]['z_truth']
        xl = recondata[:]['x']
        h.close()
        r1 = x**2 + y**2
        H1, xedges, yedges = np.histogram2d(np.nan_to_num(r1), np.nan_to_num(z), bins=(xedges, yedges))
        X, Y = np.meshgrid(xedges[1:],yedges[1:])
        plt.contourf(X,Y,np.log(np.log(np.transpose(H1)+1)+1))
        plt.xlabel('x^2+y^2:[m]')
        plt.ylabel('z:[m]')
        plt.colorbar()
        plt.plot(xt[0]**2/1e6,zt[0]/1e3,marker='o',color = 'r')
        # plt.title(os.path.join('../result/050',filename))
        plt.title('Before smooth')
        plt.show()
